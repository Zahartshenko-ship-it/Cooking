# %%
import pandas as pd

df = pd.read_csv("recipes_main.csv", index_col = 0)
# Out:
# ['помидор_(больших)',
#  'помидор_(в_собственном_соку)',
#  'помидор_(в_собственном_соку_без_кожи,_для_начинки)',
#  'помидор_(вяленые_на_солнце)',
#  'помидор_(или_300_гр_томатов_в_соке)',
#  'помидор_(красный,_большие)',
#  'помидор_(крупные)',
#  'помидор_(крупный)',
#  'помидор_(крупный,_для_салата)',
#  'помидор_(крупный_или_2_небольших)',
#  'помидор_(крупный_мясистый)',
#  'помидор_(можно_в_с/соку)',
#  'помидор_(плотный)',
#  'помидор_(свежемороженный_,_из_собственных_заготовок)',
#  'помидор_(свежий)',
#  'помидор_(сезонный_сладкий)',
#  'помидор_(сочный)',
#  'помидор_(спелые)',
#  'помидор_(спелый_сезонный_или_150_граммов_консервированных_в_собственном_соку)',
#  'помидор_(средние)',
#  'помидор_(средний_или_готовая_нарезанная_мякоть_помидора_4_стл)',
#  'помидор_(сушеный)',
#  'помидор_(черри)',
#  'помидор_соленый',
#  'помидоры_черри',
#  'помидоры_черри_(100',
#  'помидоры_черри_(для_украшения)',
#  'порошок_грибной',
#  'порошок_чесночный',
# ...

# %%
def to_standartize():
    basis = ["ананас", "апельсин", "базилик", "баклажан", "баранина", "барбарис", "бедро_куриное", "бекон", "брокколи", "брынза", "булгур", "бульон", "ванилин", "вермишель", "ветчина", "вино_белое", "вишня", "вода", "гвоздика", "говядина", "голень_куриная", "горох", "горошек_зеленый", "горчица", "грибы", "грудинка", "грудка_куриная", "джем", "желток_яичный", "зелень", "зира", "изюм", "имбирь", "йогурт", "кабачок", "кальмар", "капуста_белокочанная", "капуста_квашеная", "капуста_краснокочанная", "кардамон", "карри", "картофель", "кетчуп", "киви", "кинза", "киноа", "клюква", "колбаски", "колбаса", "консвервы_рыбные", "кориандр", "корица", "крахмал", "креветки", "крупа_гречневая", "крупа_кукурзная", "крупа_манная", "крупа_перловая", "крупа_ячневая", "кукуруза", "кумин", "кунжут", "курага", "курица", "куркума", "лайм", "лимон", "лук", "майонез", "мак", "макароны", "маслины", "масло_оливковое", "масло_подсолнечное", "масло_растительное", "масло_сливочное", "масло_топленое", "маш", "мидии", "мед", "миндаль", "молоко", "морепродукты", "морковь", "моцарелла", "мука_пшеничная", "мясо", "мята", "нут", "овощи", "огурец", "окорок", "окорочок", "оливки_зеленые", "орегано", "орех_мускатный", "орехи_грецкие", "орехи_кедровые", "орехи_кешью", "отруби", "пажитник", "паприка_сладкая", "пармезан", "перец_белый", "перец_болгарский", "перец_душистый", "перец_красный_жгучий", "перец_сладкий_зеленый", "перец_сладкий_красный", "перец_черный", "перец_чили", "петрушка", "печень", "помидор", "приправа", "пряности", "пшено", "рис", "розмарин", "рыба", "сало", "сахар", "свекла", "свинина", "сельдерей_корневой", "сельдерей_черешковый", "сливки", "смесь_перцев", "смесь_специй", "сметана", "соевый_соус", "сок_томатный", "соль", "сосиска", "соус", "специи", "сухари_панировочные", "сухофрукты", "сыр_голландский", "сыр_колбасный", "сыр_копченый", "сыр_мягкий", "сыр_плавленый", "сыр_полутвердый", "сыр_сливочный", "сыр_твердый", "сырок_плавленый", "творог", "тимьян", "тмин", "томатная_паста", "томаты_в_собственном_соку", "томаты_вяленые", "томаты_протертые", "тунец", "тушенка", "тыква", "укроп", "уксус", "фарш", "фасоль", "филе_куриное", "филе_рыбное", "хлеб", "хлопья_гречневые", "хлопья_овсяные", "хлопья_пшенные", "хлопья_рисовые", "цедра_апельсина", "цедра_лимона", "цуккини", "чернослив", "чеснок", "чечевица", "шалфей", "шампиньоны", "шафран", "шпинат", "яблоко", "яйцо_куриное", "яйцо_перепелиное"]
